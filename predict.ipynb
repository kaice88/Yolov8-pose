# %%
from ultralytics import YOLO

# %%
model = YOLO('M:/HK6/PBL5/Repos/Yolov8-pose/runs/pose/train3/weights/best.pt')
# result = model.predict('M:/HK6/PBL5/Repos/Yolov8-pose/datasets/light_dataset/images/train/light-0-5_WL_1_0001.jpg', save=True)
result = model.predict('D:/Dataset/Esp32', save=True)
# Out:
# image 1/119 D:\Dataset\Esp32\20230414160944.jpg: 480x640 1 person, 397.5ms
# image 2/119 D:\Dataset\Esp32\20230414160954.jpg: 480x640 1 person, 324.0ms
# image 3/119 D:\Dataset\Esp32\20230414160958.jpg: 480x640 2 persons, 318.7ms
# image 4/119 D:\Dataset\Esp32\20230414161004.jpg: 480x640 1 person, 308.1ms
# image 5/119 D:\Dataset\Esp32\20230414161009.jpg: 480x640 2 persons, 273.3ms
# image 6/119 D:\Dataset\Esp32\20230414161019.jpg: 480x640 2 persons, 328.1ms
# image 7/119 D:\Dataset\Esp32\20230414161030.jpg: 480x640 1 person, 365.4ms
# image 8/119 D:\Dataset\Esp32\20230414161035.jpg: 480x640 1 person, 313.1ms
# image 9/119 D:\Dataset\Esp32\20230414161040.jpg: 480x640 2 persons, 277.1ms
# image 10/119 D:\Dataset\Esp32\20230414161045.jpg: 480x640 2 persons, 320.7ms
# image 11/119 D:\Dataset\Esp32\20230414161053.jpg: 480x640 1 person, 280.3ms
# image 12/119 D:\Dataset\Esp32\20230414161059.jpg: 480x640 1 person, 279.7ms
# ...
